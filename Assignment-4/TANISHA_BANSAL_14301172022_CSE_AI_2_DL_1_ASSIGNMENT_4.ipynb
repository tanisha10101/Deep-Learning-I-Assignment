# %% [markdown]
# **SUBMITTED BY:- TANISHA BANSAL**
#
# **ROLL NO:- 14301172022**
#
# **BATCH:- CSE-AI-2**
#
# **COURSE:- DL-1 ASSIGNMENT-4**

# %% [markdown]
# **Write a program to implement different neural networks for MNIST dataset by
# varying number of neurons and layers.**

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
# Loading the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalizing the input data
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

def create_model(num_layers, num_neurons):
    model = Sequential()

    # Flattening the input layer (28x28 images to a 784-dimensional vector)
    model.add(Flatten(input_shape=(28, 28)))

    # Adding hidden layers
    for _ in range(num_layers):
        model.add(Dense(num_neurons, activation='relu'))

    # Output layer (10 neurons for 10 classes)
    model.add(Dense(10, activation='softmax'))

    # Compiling the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

#Now, we will train it
def train_and_evaluate(num_layers_list, num_neurons_list, epochs=10):
    results = {}

    for num_layers in num_layers_list:
        for num_neurons in num_neurons_list:
            print(f"\nTraining model with {num_layers} layers and {num_neurons} neurons per layer")
            model = create_model(num_layers, num_neurons)

            # Training the model
            model.fit(x_train, y_train, epochs=epochs, batch_size=128, verbose=1, validation_data=(x_test, y_test))

            # Evaluating the model on test data
            loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

            # Storing our results
            results[(num_layers, num_neurons)] = accuracy
            print(f"Test accuracy: {accuracy:.4f}")

    return results

num_layers_list = [1, 2, 3] #layers
num_neurons_list = [32, 64, 128]  # numbers of neurons in each layer

# Train and evaluate the models
results = train_and_evaluate(num_layers_list, num_neurons_list, epochs=5)

# Display the results
print("\nSummary of results:")
for config, accuracy in results.items():
    print(f"Layers: {config[0]}, Neurons: {config[1]} --> Test Accuracy: {accuracy:.4f}")
# Out:
# Training model with 1 layers and 32 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7351 - loss: 0.9167 - val_accuracy: 0.9265 - val_loss: 0.2635
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9292 - loss: 0.2557 - val_accuracy: 0.9392 - val_loss: 0.2124
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9427 - loss: 0.2065 - val_accuracy: 0.9465 - val_loss: 0.1888
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9509 - loss: 0.1764 - val_accuracy: 0.9520 - val_loss: 0.1659
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9547 - loss: 0.1586 - val_accuracy: 0.9541 - val_loss: 0.1557
# Test accuracy: 0.9541
#
# Training model with 1 layers and 64 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7985 - loss: 0.7437 - val_accuracy: 0.9332 - val_loss: 0.2402
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9375 - loss: 0.2247 - val_accuracy: 0.9482 - val_loss: 0.1790
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9521 - loss: 0.1675 - val_accuracy: 0.9579 - val_loss: 0.1461
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9629 - loss: 0.1318 - val_accuracy: 0.9623 - val_loss: 0.1251
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9695 - loss: 0.1093 - val_accuracy: 0.9668 - val_loss: 0.1148
# Test accuracy: 0.9668
#
# Training model with 1 layers and 128 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8248 - loss: 0.6356 - val_accuracy: 0.9434 - val_loss: 0.1951
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9497 - loss: 0.1766 - val_accuracy: 0.9616 - val_loss: 0.1300
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9674 - loss: 0.1194 - val_accuracy: 0.9675 - val_loss: 0.1084
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9749 - loss: 0.0895 - val_accuracy: 0.9712 - val_loss: 0.0929
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9797 - loss: 0.0714 - val_accuracy: 0.9752 - val_loss: 0.0830
# Test accuracy: 0.9752
#
# Training model with 2 layers and 32 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7214 - loss: 0.9104 - val_accuracy: 0.9238 - val_loss: 0.2587
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9328 - loss: 0.2349 - val_accuracy: 0.9410 - val_loss: 0.1977
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9461 - loss: 0.1861 - val_accuracy: 0.9500 - val_loss: 0.1722
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9551 - loss: 0.1530 - val_accuracy: 0.9517 - val_loss: 0.1630
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9586 - loss: 0.1387 - val_accuracy: 0.9558 - val_loss: 0.1462
# Test accuracy: 0.9558
#
# Training model with 2 layers and 64 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7987 - loss: 0.7075 - val_accuracy: 0.9413 - val_loss: 0.2051
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9452 - loss: 0.1893 - val_accuracy: 0.9571 - val_loss: 0.1465
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9611 - loss: 0.1326 - val_accuracy: 0.9636 - val_loss: 0.1216
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9679 - loss: 0.1112 - val_accuracy: 0.9661 - val_loss: 0.1069
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9738 - loss: 0.0894 - val_accuracy: 0.9684 - val_loss: 0.1033
# Test accuracy: 0.9684
#
# Training model with 2 layers and 128 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8372 - loss: 0.5861 - val_accuracy: 0.9552 - val_loss: 0.1473
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9605 - loss: 0.1341 - val_accuracy: 0.9686 - val_loss: 0.1036
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9735 - loss: 0.0884 - val_accuracy: 0.9698 - val_loss: 0.0951
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9807 - loss: 0.0628 - val_accuracy: 0.9731 - val_loss: 0.0855
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9855 - loss: 0.0485 - val_accuracy: 0.9742 - val_loss: 0.0808
# Test accuracy: 0.9742
#
# Training model with 3 layers and 32 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 82ms/step - accuracy: 0.7058 - loss: 0.9464 - val_accuracy: 0.9284 - val_loss: 0.2412
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9359 - loss: 0.2246 - val_accuracy: 0.9479 - val_loss: 0.1821
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9515 - loss: 0.1681 - val_accuracy: 0.9538 - val_loss: 0.1606
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9575 - loss: 0.1434 - val_accuracy: 0.9574 - val_loss: 0.1426
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9636 - loss: 0.1234 - val_accuracy: 0.9592 - val_loss: 0.1416
# Test accuracy: 0.9592
#
# Training model with 3 layers and 64 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7892 - loss: 0.7113 - val_accuracy: 0.9477 - val_loss: 0.1760
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9513 - loss: 0.1677 - val_accuracy: 0.9623 - val_loss: 0.1297
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9656 - loss: 0.1146 - val_accuracy: 0.9665 - val_loss: 0.1123
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9733 - loss: 0.0848 - val_accuracy: 0.9691 - val_loss: 0.0986
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9800 - loss: 0.0688 - val_accuracy: 0.9699 - val_loss: 0.0968
# Test accuracy: 0.9699
#
# Training model with 3 layers and 128 neurons per layer
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8336 - loss: 0.5740 - val_accuracy: 0.9594 - val_loss: 0.1345
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9625 - loss: 0.1246 - val_accuracy: 0.9683 - val_loss: 0.0983
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9760 - loss: 0.0803 - val_accuracy: 0.9723 - val_loss: 0.0856
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9827 - loss: 0.0570 - val_accuracy: 0.9763 - val_loss: 0.0738
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9862 - loss: 0.0462 - val_accuracy: 0.9736 - val_loss: 0.0880
# Test accuracy: 0.9736
#
# Summary of results:
# Layers: 1, Neurons: 32 --> Test Accuracy: 0.9541
# Layers: 1, Neurons: 64 --> Test Accuracy: 0.9668
# Layers: 1, Neurons: 128 --> Test Accuracy: 0.9752
# Layers: 2, Neurons: 32 --> Test Accuracy: 0.9558
# Layers: 2, Neurons: 64 --> Test Accuracy: 0.9684
# Layers: 2, Neurons: 128 --> Test Accuracy: 0.9742
# Layers: 3, Neurons: 32 --> Test Accuracy: 0.9592
# Layers: 3, Neurons: 64 --> Test Accuracy: 0.9699
# Layers: 3, Neurons: 128 --> Test Accuracy: 0.9736
